# %%
import torch as tn
import torchtt as tntt
import TTCME
import matplotlib.pyplot as plt 
import datetime
import numpy as np
import pickle 

tn.set_default_tensor_type(tn.DoubleTensor)
qtt = True

# %% [markdown]
# Define the model. The 4 reaction coefficients are the parameters.

# %%
r1m = TTCME.ChemicalReaction(['mRNA','protein'],'mRNA->', 'c1', params = ['c1'])
r2m = TTCME.ChemicalReaction(['mRNA','protein'],'mRNA->mRNA+protein', 'c2', params = ['c2'])
r3m = TTCME.ChemicalReaction(['mRNA','protein'],'->mRNA', 'c3', params = ['c3'])
r4m = TTCME.ChemicalReaction(['mRNA','protein'],'protein->', 'c4', params = ['c4'])

mdl = TTCME.ReactionSystem(['mRNA','protein'],[r1m, r2m, r3m, r4m], params= ['c1','c2','c3','c4'])

rates = np.array([0.002,0.015,0.1,0.01])
IC = [2,4]
N = [64,64]

# %% [markdown]
# Load the measurements and the reference from the file.

# %%
with open(r"simplegene_64_500k.pickle", "rb") as input_file:
    dct = pickle.load(input_file) 

No = dct['time_observation'].size
time_observation = dct['time_observation']
reaction_time = dct['reaction_time']
reaction_jumps = dct['reaction_jumps']
reaction_indices = dct['reaction_indices']
observations = dct['observations']
observations_noise = dct['observations_noise']
dT = time_observation[1]-time_observation[0]
sigma = dct['sigma']
sample_posterior_mcmc = dct['sample']

# %% [markdown]
# Plot the observations and the true trajectory.

# %%
plt.figure()
plt.plot(np.repeat(reaction_time,2)[1:],np.repeat(reaction_jumps[:,0],2)[:-1],'b')
plt.plot(np.repeat(reaction_time,2)[1:],np.repeat(reaction_jumps[:,1],2)[:-1],'r') 
plt.scatter(time_observation,observations_noise[:,0],c='b',s=20)
plt.scatter(time_observation,observations_noise[:,1],c='r',marker='x',s=20)
plt.xlabel('t [s]')
plt.ylabel('#individuals')
plt.legend(['mRNA','Protein','mRNA observation','Protein observation'])

# %% [markdown]
# Define the basis of the parameter space.

# %%
Nl = 64
mult = 6
param_range = [[0,rc*mult] for rc in rates]
basis_param = [TTCME.basis.BSplineBasis(Nl,[p[0],p[1]],deg = 2) for p in param_range]

# %% [markdown]
# Define the prior distribution (independent gamma).

# %%
mu = rates
var = rates / np.array([1000,350,25,600])
alpha_prior = mu**2/var
beta_prior = mu/var
prior = TTCME.GammaPDF(alpha_prior, beta_prior, basis_param, ['c1','c2','c3','c4'])

# %% [markdown]
# Define the initial condition and the joint PDF.

# %%
p_ic = TTCME.pdf.SingularPMF(N,IC,['mRNA','protein'])
p0 = p_ic ** prior
p0.normalize()

p = p0.dofs.clone()

print(p0)
# Out:
# Probability density function:
# p(mRNA,protein,c1,c2,c3,c4)
#
# Basis:
# <TTCME.basis.DiracDeltaBase object at 0x7f4c3614a250>
# <TTCME.basis.DiracDeltaBase object at 0x7f4c35fc6a90>
# <TTCME.basis.BSplineBasis object at 0x7f4c357d1b80>
# <TTCME.basis.BSplineBasis object at 0x7f4c36b5d520>
# <TTCME.basis.BSplineBasis object at 0x7f4c36b5dac0>
# <TTCME.basis.BSplineBasis object at 0x7f4c357d8df0>
#
# DoF:
# TT with sizes and ranks:
# N = [64, 64, 64, 64, 64, 64]
# R = [1, 1, 1, 1, 1, 1, 1]
#
# Device: cpu, dtype: torch.float64
# #entries 384 compression 5.587935447692871e-09

# %% [markdown]
# Instantiate the observation operator.

# %%
obs_operator = TTCME.pdf.GaussianObservation(N, [sigma]*2)

# %% [markdown]
# Compute the CME operator for the parameter dependent case.

# %%
Stt,Mtt,Mtt_inv = mdl.generator_tt_galerkin(N, basis_param)
Att = Mtt_inv @ Stt

# %% [markdown]
# Instantiate the TT time-domain solver. If the `qtt` flag is `True`, the result will be performed in the QTT format.

# %%
if qtt:
    A_qtt = Att.to_qtt()
    fwd_int = TTCME.TimeIntegrator.TTInt(A_qtt, epsilon = 1e-5, N_max = 8, dt_max = 1.0,method='cheby')
    Nbs = 4
    p = p.to_qtt()
else:
    fwd_int = TTCME.TimeIntegrator.TTInt(Att, epsilon = 1e-5, N_max = 64, dt_max = 1.0,method='crank–nicolson')
    Nbs = 4

# %% [markdown]
# Perform the perameter inference.

# %%
posterior_list  =[]
joint_pdf = p0.copy()
for i in range(1,No):
    
    y = observations_noise[i,:]

    
    po = obs_operator.likelihood(y) 
    #po = po / po.sum()
    
    po = po ** tntt.ones([Nl]*4)

    if qtt: po = po.to_qtt()
    
    print('new observation ',i,'/',No,' at time ',time_observation[i],' ',y)
    
    tme = datetime.datetime.now()
    p = fwd_int.solve(p, dT, intervals = Nbs,qtt = qtt,verb = False, rounding=True, device = 'cuda:0')
    tme = datetime.datetime.now() - tme
    
    
    print('\tmax rank ',max(p.R))
    p_pred = p
    p_post = po * p_pred
    p_post = p_post.round(1e-10)
    print('\tmax rank (after observation) ',max(p_post.R))
    
    if qtt:
        joint_pdf.dofs = tntt.reshape(p_post,joint_pdf.dofs.N)
        Z = joint_pdf.Z
        joint_pdf.normalize()
        p = p_post / Z
    else:
        joint_pdf.dofs = p_post.clone()
        joint_pdf.normalize()
        p = joint_pdf.dofs.clone()

    
    posterior_pdf = joint_pdf.marginal([0,1])
    posterior_pdf.round(1e-10)
    posterior_list.append(posterior_pdf.copy())



    E = posterior_pdf.expected_value()
    
    print('\tExpected value computed posterior ' ,E)
    # print('\tVariance computed posterior       ' ,V)
    print('\tposterior size ',tntt.numel(p)*8 / 1000000,' MB')
    print('\telapsed ',tme)
# Out:
# new observation  1 / 64  at time  4   [2.51919804 3.08774773]
# 	max rank  71
# 	max rank (after observation)  71
# 	Expected value computed posterior  [tensor(0.0020), tensor(0.0147), tensor(0.0957), tensor(0.0105)]
# 	posterior size  0.62416  MB
# 	elapsed  0:00:12.555185
# new observation  2 / 64  at time  8   [3.31271408 4.51143619]
# 	max rank  92
# 	max rank (after observation)  92
# 	Expected value computed posterior  [tensor(0.0020), tensor(0.0150), tensor(0.1089), tensor(0.0098)]
# 	posterior size  0.990896  MB
# 	elapsed  0:00:10.146567
# new observation  3 / 64  at time  12   [3.5537123  5.04546854]
# 	max rank  94
# 	max rank (after observation)  94
# 	Expected value computed posterior  [tensor(0.0020), tensor(0.0162), tensor(0.1063), tensor(0.0095)]
# 	posterior size  1.056016  MB
# 	elapsed  0:00:10.325606
# new observation  4 / 64  at time  16   [5.82494567 4.10897851]
# 	max rank  102
# 	max rank (after observation)  102
# 	Expected value computed posterior  [tensor(0.0019), tensor(0.0149), tensor(0.1467), tensor(0.0097)]
# 	posterior size  1.219152  MB
# 	elapsed  0:00:10.777393
# new observation  5 / 64  at time  20   [5.55259343 3.12925302]
# 	max rank  119
# 	max rank (after observation)  119
# 	Expected value computed posterior  [tensor(0.0019), tensor(0.0139), tensor(0.1374), tensor(0.0104)]
# 	posterior size  1.650816  MB
# 	elapsed  0:00:12.762942
# new observation  6 / 64  at time  24   [5.47387213 4.71830139]
# 	max rank  120
# 	max rank (after observation)  120
# 	Expected value computed posterior  [tensor(0.0019), tensor(0.0145), tensor(0.1274), tensor(0.0098)]
# 	posterior size  1.7112  MB
# 	elapsed  0:00:11.996999
# new observation  7 / 64  at time  28   [5.71189631 2.78985279]
# 	max rank  115
# 	max rank (after observation)  115
# 	Expected value computed posterior  [tensor(0.0019), tensor(0.0133), tensor(0.1219), tensor(0.0109)]
# 	posterior size  1.591504  MB
# 	elapsed  0:00:11.669861
# new observation  8 / 64  at time  32   [5.46883519 4.11868613]
# 	max rank  120
# 	max rank (after observation)  120
# 	Expected value computed posterior  [tensor(0.0019), tensor(0.0136), tensor(0.1135), tensor(0.0103)]
# 	posterior size  1.659536  MB
# 	elapsed  0:00:11.883413
# new observation  9 / 64  at time  36   [6.00047868 5.03262659]
# 	max rank  111
# 	max rank (after observation)  111
# 	Expected value computed posterior  [tensor(0.0019), tensor(0.0147), tensor(0.1100), tensor(0.0101)]
# 	posterior size  1.5108  MB
# 	elapsed  0:00:11.379960
# new observation  10 / 64  at time  40   [6.31623795 3.98485997]
# 	max rank  111
# 	max rank (after observation)  111
# 	Expected value computed posterior  [tensor(0.0019), tensor(0.0135), tensor(0.1058), tensor(0.0103)]
# 	posterior size  1.51368  MB
# 	elapsed  0:00:11.415875
# new observation  11 / 64  at time  44   [9.47024466 3.67878162]
# 	max rank  111
# 	max rank (after observation)  111
# 	Expected value computed posterior  [tensor(0.0019), tensor(0.0125), tensor(0.1422), tensor(0.0103)]
# 	posterior size  1.481104  MB
# 	elapsed  0:00:11.238685
# new observation  12 / 64  at time  48   [11.52008962  5.45853887]
# 	max rank  131
# 	max rank (after observation)  131
# 	Expected value computed posterior  [tensor(0.0018), tensor(0.0138), tensor(0.1645), tensor(0.0102)]
# 	posterior size  2.159632  MB
# 	elapsed  0:00:12.363479
# new observation  13 / 64  at time  52   [11.21460679  5.88188817]
# 	max rank  142
# 	max rank (after observation)  142
# 	Expected value computed posterior  [tensor(0.0018), tensor(0.0141), tensor(0.1569), tensor(0.0101)]
# 	posterior size  2.476368  MB
# 	elapsed  0:00:13.492379
# new observation  14 / 64  at time  56   [11.32090891  5.83416972]
# 	max rank  141
# 	max rank (after observation)  141
# 	Expected value computed posterior  [tensor(0.0018), tensor(0.0135), tensor(0.1506), tensor(0.0099)]
# 	posterior size  2.394016  MB
# 	elapsed  0:00:13.365554
# new observation  15 / 64  at time  60   [11.69703611  5.46162903]
# 	max rank  142
# 	max rank (after observation)  142
# 	Expected value computed posterior  [tensor(0.0018), tensor(0.0127), tensor(0.1486), tensor(0.0099)]
# 	posterior size  2.405712  MB
# 	elapsed  0:00:13.197748
# new observation  16 / 64  at time  64   [10.90376701  8.56440617]
# 	max rank  149
# 	max rank (after observation)  149
# 	Expected value computed posterior  [tensor(0.0018), tensor(0.0154), tensor(0.1381), tensor(0.0099)]
# 	posterior size  2.560416  MB
# 	elapsed  0:00:13.366854
# new observation  17 / 64  at time  68   [11.210426    9.39429447]
# 	max rank  156
# 	max rank (after observation)  156
# 	Expected value computed posterior  [tensor(0.0018), tensor(0.0161), tensor(0.1328), tensor(0.0097)]
# 	posterior size  2.781824  MB
# 	elapsed  0:00:13.944322
# new observation  18 / 64  at time  72   [10.87056654 12.70917657]
# 	max rank  157
# 	max rank (after observation)  157
# 	Expected value computed posterior  [tensor(0.0018), tensor(0.0195), tensor(0.1264), tensor(0.0098)]
# 	posterior size  2.844864  MB
# 	elapsed  0:00:13.978526
# new observation  19 / 64  at time  76   [10.36978969 13.2322874 ]
# 	max rank  169
# 	max rank (after observation)  169
# 	Expected value computed posterior  [tensor(0.0018), tensor(0.0196), tensor(0.1213), tensor(0.0095)]
# 	posterior size  3.258416  MB
# 	elapsed  0:00:15.019326
# new observation  20 / 64  at time  80   [10.46487955 15.40211135]
# 	max rank  173
# 	max rank (after observation)  173
# 	Expected value computed posterior  [tensor(0.0019), tensor(0.0211), tensor(0.1174), tensor(0.0093)]
# 	posterior size  3.418256  MB
# 	elapsed  0:00:15.368514
# new observation  21 / 64  at time  84   [10.92163225 16.00519501]
# 	max rank  184
# 	max rank (after observation)  184
# 	Expected value computed posterior  [tensor(0.0018), tensor(0.0212), tensor(0.1140), tensor(0.0090)]
# 	posterior size  3.686864  MB
# 	elapsed  0:00:15.877529
# new observation  22 / 64  at time  88   [13.55644778 12.51103188]
# 	max rank  191
# 	max rank (after observation)  191
# 	Expected value computed posterior  [tensor(0.0018), tensor(0.0209), tensor(0.1295), tensor(0.0116)]
# 	posterior size  3.843072  MB
# 	elapsed  0:00:16.202887
# new observation  23 / 64  at time  92   [13.86639133 13.24166891]
# 	max rank  241
# 	max rank (after observation)  241
# 	Expected value computed posterior  [tensor(0.0017), tensor(0.0204), tensor(0.1308), tensor(0.0114)]
# 	posterior size  6.490688  MB
# 	elapsed  0:00:21.516044
# new observation  24 / 64  at time  96   [14.79983363 12.22494021]
# 	max rank  264
# 	max rank (after observation)  264
# 	Expected value computed posterior  [tensor(0.0017), tensor(0.0197), tensor(0.1338), tensor(0.0118)]
# 	posterior size  7.409184  MB
# 	elapsed  0:00:22.628817
# new observation  25 / 64  at time  100   [16.19979698 12.9242126 ]
# 	max rank  274
# 	max rank (after observation)  274
# 	Expected value computed posterior  [tensor(0.0017), tensor(0.0193), tensor(0.1407), tensor(0.0115)]
# 	posterior size  7.65608  MB
# 	elapsed  0:00:26.657347
# new observation  26 / 64  at time  104   [14.72103297 13.08040342]
# 	max rank  238
# 	max rank (after observation)  238
# 	Expected value computed posterior  [tensor(0.0019), tensor(0.0187), tensor(0.1339), tensor(0.0113)]
# 	posterior size  5.892272  MB
# 	elapsed  0:00:23.021244
# new observation  27 / 64  at time  108   [16.03826253 11.85139792]
# 	max rank  241
# 	max rank (after observation)  241
# 	Expected value computed posterior  [tensor(0.0018), tensor(0.0181), tensor(0.1353), tensor(0.0119)]
# 	posterior size  6.127136  MB
# 	elapsed  0:00:21.185672
# new observation  28 / 64  at time  112   [14.35286299 10.55740999]
# 	max rank  241
# 	max rank (after observation)  241
# 	Expected value computed posterior  [tensor(0.0021), tensor(0.0177), tensor(0.1297), tensor(0.0126)]
# 	posterior size  6.041408  MB
# 	elapsed  0:00:21.618686
# new observation  29 / 64  at time  116   [14.90625174 12.75322   ]
# 	max rank  251
# 	max rank (after observation)  251
# 	Expected value computed posterior  [tensor(0.0020), tensor(0.0183), tensor(0.1264), tensor(0.0124)]
# 	posterior size  6.676864  MB
# 	elapsed  0:00:21.884292
# new observation  30 / 64  at time  120   [15.94229352 12.8246277 ]
# 	max rank  240
# 	max rank (after observation)  240
# 	Expected value computed posterior  [tensor(0.0020), tensor(0.0180), tensor(0.1281), tensor(0.0122)]
# 	posterior size  6.084928  MB
# 	elapsed  0:00:23.291998
# new observation  31 / 64  at time  124   [16.02234869 14.55112184]
# 	max rank  244
# 	max rank (after observation)  244
# 	Expected value computed posterior  [tensor(0.0019), tensor(0.0184), tensor(0.1263), tensor(0.0120)]
# 	posterior size  6.18464  MB
# 	elapsed  0:00:21.656683
# new observation  32 / 64  at time  128   [16.44543675 14.42440742]
# 	max rank  229
# 	max rank (after observation)  229
# 	Expected value computed posterior  [tensor(0.0018), tensor(0.0180), tensor(0.1246), tensor(0.0118)]
# 	posterior size  5.525056  MB
# 	elapsed  0:00:20.460362
# new observation  33 / 64  at time  132   [15.69384865 16.5706251 ]
# 	max rank  234
# 	max rank (after observation)  234
# 	Expected value computed posterior  [tensor(0.0018), tensor(0.0186), tensor(0.1199), tensor(0.0116)]
# 	posterior size  5.69496  MB
# 	elapsed  0:00:21.416961
# new observation  34 / 64  at time  136   [17.56643224 15.19179163]
# 	max rank  226
# 	max rank (after observation)  226
# 	Expected value computed posterior  [tensor(0.0018), tensor(0.0181), tensor(0.1247), tensor(0.0119)]
# 	posterior size  5.429504  MB
# 	elapsed  0:00:20.156313
# new observation  35 / 64  at time  140   [17.78148492 16.17374441]
# 	max rank  228
# 	max rank (after observation)  228
# 	Expected value computed posterior  [tensor(0.0017), tensor(0.0179), tensor(0.1248), tensor(0.0116)]
# 	posterior size  5.372832  MB
# 	elapsed  0:00:20.106266
# new observation  36 / 64  at time  144   [16.38491048 17.28553907]
# 	max rank  227
# 	max rank (after observation)  227
# 	Expected value computed posterior  [tensor(0.0019), tensor(0.0180), tensor(0.1199), tensor(0.0114)]
# 	posterior size  5.317776  MB
# 	elapsed  0:00:20.032738
# new observation  37 / 64  at time  148   [17.03003061 16.887238  ]
# 	max rank  224
# 	max rank (after observation)  224
# 	Expected value computed posterior  [tensor(0.0018), tensor(0.0175), tensor(0.1172), tensor(0.0112)]
# 	posterior size  5.26048  MB
# 	elapsed  0:00:19.891984
# new observation  38 / 64  at time  152   [17.67486307 17.67514987]
# 	max rank  229
# 	max rank (after observation)  229
# 	Expected value computed posterior  [tensor(0.0017), tensor(0.0173), tensor(0.1170), tensor(0.0109)]
# 	posterior size  5.36784  MB
# 	elapsed  0:00:19.687076
# new observation  39 / 64  at time  156   [17.80667334 18.43299477]
# 	max rank  239
# 	max rank (after observation)  239
# 	Expected value computed posterior  [tensor(0.0017), tensor(0.0172), tensor(0.1161), tensor(0.0106)]
# 	posterior size  5.700704  MB
# 	elapsed  0:00:20.671982
# new observation  40 / 64  at time  160   [18.8736168  16.29487693]
# 	max rank  238
# 	max rank (after observation)  238
# 	Expected value computed posterior  [tensor(0.0016), tensor(0.0170), tensor(0.1182), tensor(0.0115)]
# 	posterior size  5.61152  MB
# 	elapsed  0:00:20.375287
# new observation  41 / 64  at time  164   [19.81087924 17.82708967]
# 	max rank  247
# 	max rank (after observation)  247
# 	Expected value computed posterior  [tensor(0.0016), tensor(0.0169), tensor(0.1209), tensor(0.0112)]
# 	posterior size  5.879856  MB
# 	elapsed  0:00:24.722855
# new observation  42 / 64  at time  168   [19.19003123 16.09449734]
# 	max rank  237
# 	max rank (after observation)  237
# 	Expected value computed posterior  [tensor(0.0016), tensor(0.0166), tensor(0.1173), tensor(0.0117)]
# 	posterior size  5.368736  MB
# 	elapsed  0:00:20.970547
# new observation  43 / 64  at time  172   [19.6616491 14.8677057]
# 	max rank  231
# 	max rank (after observation)  231
# 	Expected value computed posterior  [tensor(0.0016), tensor(0.0164), tensor(0.1164), tensor(0.0122)]
# 	posterior size  5.227056  MB
# 	elapsed  0:00:20.195797
# new observation  44 / 64  at time  176   [19.54251069 16.76051792]
# 	max rank  230
# 	max rank (after observation)  230
# 	Expected value computed posterior  [tensor(0.0015), tensor(0.0166), tensor(0.1145), tensor(0.0120)]
# 	posterior size  5.160096  MB
# 	elapsed  0:00:19.862308
# new observation  45 / 64  at time  180   [19.52359225 15.46197421]
# 	max rank  225
# 	max rank (after observation)  225
# 	Expected value computed posterior  [tensor(0.0015), tensor(0.0162), tensor(0.1126), tensor(0.0122)]
# 	posterior size  4.99904  MB
# 	elapsed  0:00:21.285476
# new observation  46 / 64  at time  184   [18.94292493 15.20290122]
# 	max rank  229
# 	max rank (after observation)  229
# 	Expected value computed posterior  [tensor(0.0016), tensor(0.0159), tensor(0.1099), tensor(0.0122)]
# 	posterior size  5.083184  MB
# 	elapsed  0:00:19.506587
# new observation  47 / 64  at time  188   [19.1442259  16.78260575]
# 	max rank  228
# 	max rank (after observation)  228
# 	Expected value computed posterior  [tensor(0.0016), tensor(0.0161), tensor(0.1076), tensor(0.0120)]
# 	posterior size  5.083392  MB
# 	elapsed  0:00:19.313693
# new observation  48 / 64  at time  192   [19.17937782 15.80587753]
# 	max rank  227
# 	max rank (after observation)  227
# 	Expected value computed posterior  [tensor(0.0015), tensor(0.0157), tensor(0.1054), tensor(0.0120)]
# 	posterior size  5.00344  MB
# 	elapsed  0:00:20.753578
# new observation  49 / 64  at time  196   [20.06437315 15.70480234]
# 	max rank  233
# 	max rank (after observation)  233
# 	Expected value computed posterior  [tensor(0.0015), tensor(0.0153), tensor(0.1069), tensor(0.0118)]
# 	posterior size  5.23088  MB
# 	elapsed  0:00:19.237732
# new observation  50 / 64  at time  200   [17.94728286 16.35021418]
# 	max rank  239
# 	max rank (after observation)  239
# 	Expected value computed posterior  [tensor(0.0018), tensor(0.0151), tensor(0.1055), tensor(0.0116)]
# 	posterior size  5.428048  MB
# 	elapsed  0:00:19.895654
# new observation  51 / 64  at time  204   [20.04642594 16.9315141 ]
# 	max rank  259
# 	max rank (after observation)  259
# 	Expected value computed posterior  [tensor(0.0017), tensor(0.0149), tensor(0.1071), tensor(0.0113)]
# 	posterior size  6.298176  MB
# 	elapsed  0:00:22.700099
# new observation  52 / 64  at time  208   [17.53475529 17.16374862]
# 	max rank  261
# 	max rank (after observation)  261
# 	Expected value computed posterior  [tensor(0.0023), tensor(0.0147), tensor(0.1080), tensor(0.0111)]
# 	posterior size  6.200576  MB
# 	elapsed  0:00:23.785799
# new observation  53 / 64  at time  212   [20.65150654 19.29529882]
# 	max rank  267
# 	max rank (after observation)  267
# 	Expected value computed posterior  [tensor(0.0021), tensor(0.0151), tensor(0.1134), tensor(0.0111)]
# 	posterior size  6.7248  MB
# 	elapsed  0:00:22.322820
# new observation  54 / 64  at time  216   [19.92793703 19.64179299]
# 	max rank  277
# 	max rank (after observation)  277
# 	Expected value computed posterior  [tensor(0.0020), tensor(0.0150), tensor(0.1104), tensor(0.0108)]
# 	posterior size  7.018384  MB
# 	elapsed  0:00:25.713431
# new observation  55 / 64  at time  220   [20.05180709 20.25214072]
# 	max rank  272
# 	max rank (after observation)  272
# 	Expected value computed posterior  [tensor(0.0020), tensor(0.0148), tensor(0.1079), tensor(0.0106)]
# 	posterior size  6.706256  MB
# 	elapsed  0:00:23.388061
# new observation  56 / 64  at time  224   [20.41255322 23.30699954]
# 	max rank  272
# 	max rank (after observation)  272
# 	Expected value computed posterior  [tensor(0.0019), tensor(0.0157), tensor(0.1063), tensor(0.0107)]
# 	posterior size  6.764288  MB
# 	elapsed  0:00:22.943292
# new observation  57 / 64  at time  228   [20.6553463  23.62417368]
# 	max rank  277
# 	max rank (after observation)  277
# 	Expected value computed posterior  [tensor(0.0018), tensor(0.0155), tensor(0.1056), tensor(0.0105)]
# 	posterior size  6.916048  MB
# 	elapsed  0:00:25.999516
# new observation  58 / 64  at time  232   [21.31814048 23.42117792]
# 	max rank  286
# 	max rank (after observation)  286
# 	Expected value computed posterior  [tensor(0.0018), tensor(0.0152), tensor(0.1059), tensor(0.0103)]
# 	posterior size  7.23552  MB
# 	elapsed  0:00:24.660971
# new observation  59 / 64  at time  236   [20.30733996 23.51069556]
# 	max rank  275
# 	max rank (after observation)  275
# 	Expected value computed posterior  [tensor(0.0018), tensor(0.0150), tensor(0.1041), tensor(0.0101)]
# 	posterior size  6.715296  MB
# 	elapsed  0:00:23.888090
# new observation  60 / 64  at time  240   [20.33413625 22.59523226]
# 	max rank  276
# 	max rank (after observation)  276
# 	Expected value computed posterior  [tensor(0.0019), tensor(0.0148), tensor(0.1033), tensor(0.0102)]
# 	posterior size  6.858704  MB
# 	elapsed  0:00:23.649821
# new observation  61 / 64  at time  244   [19.54593771 21.7561447 ]
# 	max rank  285
# 	max rank (after observation)  285
# 	Expected value computed posterior  [tensor(0.0021), tensor(0.0146), tensor(0.1035), tensor(0.0103)]
# 	posterior size  7.317168  MB
# 	elapsed  0:00:24.353909
# new observation  62 / 64  at time  248   [20.04755872 20.59233427]
# 	max rank  285
# 	max rank (after observation)  285
# 	Expected value computed posterior  [tensor(0.0020), tensor(0.0145), tensor(0.1015), tensor(0.0106)]
# 	posterior size  7.235984  MB
# 	elapsed  0:00:24.708883
# new observation  63 / 64  at time  252   [20.31851647 23.73036271]
# 	max rank  287
# 	max rank (after observation)  287
# 	Expected value computed posterior  [tensor(0.0019), tensor(0.0151), tensor(0.0999), tensor(0.0106)]
# 	posterior size  7.294448  MB
# 	elapsed  0:00:24.256018

# %%
posterior_pdf.normalize()
nburn = 200000

E = posterior_pdf.expected_value()
C = posterior_pdf.covariance_matrix()
V = np.diag(C)

print()
print('Exact rates:                      ',rates)
print('')
print('Expected value computed posterior ' ,E)
print('Variance computed posterior       ' ,V)
# print('Computed modes:                   ',theta_mode)
print('')
print('Expected MCMC posterior           ' ,np.mean(sample_posterior_mcmc[nburn:,:],0))
print('Variance MCMC posterior           ' ,np.std(sample_posterior_mcmc[nburn:,:],0)**2)
print('')
print('Relative absolute error exp       ',np.abs(np.mean(sample_posterior_mcmc[nburn:,:],0)-E)/E * 100,' %')
print('Relative absolute error var       ',np.abs(np.std(sample_posterior_mcmc[nburn:,:],0)**2-V)/V * 100,' %')
print('')
print('Expected value prior              ' ,alpha_prior/beta_prior)
print('Variance computed prior           ' ,alpha_prior/beta_prior/beta_prior)
print('')


post_1 = posterior_pdf.marginal([1,2,3])
post_2 = posterior_pdf.marginal([0,2,3])
post_3 = posterior_pdf.marginal([0,1,3])
post_4 = posterior_pdf.marginal([0,1,2])


for i in range(4):
    pr = prior.marginal([j for j in range(4) if i!=j])
    po = posterior_pdf.marginal([j for j in range(4) if i!=j])
    x = np.linspace(param_range[i][0],param_range[i][1],1000)
    
    
    plt.figure()
    plt.plot(x, po[x].numpy())
    plt.hist(sample_posterior_mcmc[nburn:,i],bins=128,density=True,color='c',alpha=0.4)
    plt.axvline(rates[i],c='r',linestyle=':')
    plt.plot(x, pr[x].numpy())
# Out:
# Exact rates:                       [0.002 0.015 0.1   0.01 ]
#
# Expected value computed posterior  [tensor(0.0019), tensor(0.0151), tensor(0.0999), tensor(0.0106)]
# Variance computed posterior        [1.03411037e-06 8.67365560e-06 5.41684596e-04 7.62404402e-06]
#
# Expected MCMC posterior            [0.00192225 0.01507772 0.09992543 0.01052629]
# Variance MCMC posterior            [9.97549884e-07 8.49855730e-06 5.23342740e-04 7.51823318e-06]
#
# Relative absolute error exp        [0.11505088 0.30965727 0.046077   0.46852762]  %
# Relative absolute error var        [3.53545279 2.01873711 3.3860768  1.38785711]  %
#
# Expected value prior               [0.002 0.015 0.1   0.01 ]
# Variance computed prior            [2.00000000e-06 4.28571429e-05 4.00000000e-03 1.66666667e-05]

# %%
plt.figure(figsize = [20,15])

k = 0
for i in range(4):
    for j in range(4):
        k += 1
        if i==j:
            plt.subplot(4, 4, k)
            
            theta = np.linspace(param_range[i][0],param_range[i][1],1000)
            pr = prior.marginal([k for k in range(4) if i!=k])[theta].numpy()
            po = posterior_pdf.marginal([k for k in range(4) if i!=k])[theta].numpy()
           
            plt.plot(theta,po/np.max(po)*np.max(theta))
            count, bins = np.histogram(sample_posterior_mcmc[nburn:,i],bins=128,density=True)
            count = count/np.max(po)*np.max(theta)
            plt.hist(bins[:-1], bins, weights=count,color='c',alpha=0.4)
            plt.axvline(rates[i],c='r',linestyle=':')
            plt.plot(theta,pr/np.max(po)*np.max(theta),'g:')
            
        else:
            plt.subplot(4, 4, k)
             
            if j<i: 
                theta1 = np.linspace(param_range[j][0],param_range[j][1],127)
                theta2 = np.linspace(param_range[i][0],param_range[i][1],128)
                
                T1, T2 = np.meshgrid(theta1, theta2)
                po = posterior_pdf.marginal([k for k in range(4) if i!=k and j!=k])
                po.normalize()
                po = po[theta1,theta2].numpy().T
                

                counts,ybins,xbins,image = plt.hist2d(sample_posterior_mcmc[nburn:,j],sample_posterior_mcmc[nburn:,i],bins=100,density = True, range =[[T1.min(), T1.max()],[T2.min(), T2.max()]])
                plt.contour(counts.T,extent=[T1.min(), T1.max(), T2.min(), T2.max()],linewidths=0.5,levels=10, cmap =plt.cm.Greens)

                plt.contourf(T1, T2, po, cmap='gray_r', levels =12)

                plt.axvline(rates[j],c='r',linestyle=':',linewidth=1)
                plt.axhline(rates[i],c='r',linestyle=':',linewidth=1)
            else: 
                theta1 = np.linspace(param_range[i][0],param_range[i][1],127)
                theta2 = np.linspace(param_range[j][0],param_range[j][1],128)
                
                T1, T2 = np.meshgrid(theta1, theta2)
                po = posterior_pdf.marginal([k for k in range(4) if i!=k and j!=k])
                po.normalize()
                po = po[theta1,theta2].numpy().T

                counts,ybins,xbins,image = plt.hist2d(sample_posterior_mcmc[nburn:,j],sample_posterior_mcmc[nburn:,i],bins=100,density = True, range =[[T2.min(), T2.max()],[T1.min(), T1.max()]])
                plt.contour(counts.T,extent=[T2.min(), T2.max(), T1.min(), T1.max()],linewidths=0.5,levels=10, cmap =plt.cm.Greens)

                plt.contourf(T2, T1, po, cmap='gray_r', levels =32)

                plt.axvline(rates[j],c='r',linestyle=':',linewidth=1)
                plt.axhline(rates[i],c='r',linestyle=':',linewidth=1)
        
        if i==3: plt.xlabel(r'$\theta_'+str(j+1)+'$')
        if j==0: plt.ylabel(r'$\theta_'+str(i+1)+'$')
        
        if j>0: plt.yticks([])
        if i<3: plt.xticks([])
